# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n.pt")

# %%
model.export(
    format="engine", 
    imgsz=320,
    #int8=True,
    batch=1,
    simplify=True,
    half=True, 
    nms=True, 
    opset=21,
    device="cuda:0")
# Out:
# Ultralytics 8.3.221 🚀 Python-3.10.12 torch-2.8.0 CUDA:0 (Orin, 7620MiB)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# PyTorch: starting from 'yolo11n.pt' with input shape (1, 3, 320, 320) BCHW and output shape(s) (1, 300, 6) (5.4 MB)
#
# ONNX: starting export with onnx 1.19.1 opset 21...
# ONNX: slimming with onnxslim 0.1.71...
# 2025-10-26 13:23:17.023026082 [W:onnxruntime:Default, device_discovery.cc:164 DiscoverDevicesForPlatform] GPU device discovery failed: device_discovery.cc:89 ReadFileContents Failed to open file: "/sys/class/drm/card1/device/vendor"
# ONNX: export success ✅ 3.2s, saved as 'yolo11n.onnx' (10.2 MB)
#
# TensorRT: starting export with TensorRT 10.3.0...
# [10/26/2025-13:23:19] [TRT] [I] [MemUsageChange] Init CUDA: CPU +2, GPU +0, now: CPU 719, GPU 4462 (MiB)
# [10/26/2025-13:23:21] [TRT] [I] [MemUsageChange] Init builder kernel library: CPU +927, GPU +1090, now: CPU 1689, GPU 5589 (MiB)
# ...
