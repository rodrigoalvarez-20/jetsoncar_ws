# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11m.pt")

# %%
model.export(format="onnx", batch_size=1, imgsz=)
# Out:
# WARNING ⚠️ TensorRT requires GPU export, automatically assigning device=0
# Ultralytics 8.3.218 🚀 Python-3.10.12 torch-2.5.0a0+872d972e41.nv24.08 CUDA:0 (Orin, 7620MiB)
# NvMapMemAllocInternalTagged: 1075072515 error 12
# NvMapMemHandleAlloc: error 0
# NvMapMemAllocInternalTagged: 1075072515 error 12
# NvMapMemHandleAlloc: error 0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model.export(format="engine")
#
# File ~/.local/lib/python3.10/site-packages/ultralytics/engine/model.py:736, in Model.export(self, **kwargs)
#     728 custom = {
#     729     "imgsz": self.model.args["imgsz"],
#     730     "batch": 1,
#    (...)
#     733     "verbose": False,
#     734 }  # method defaults
#     735 args = {**self.overrides, **custom, **kwargs, "mode": "export"}  # highest priority args on the right
# ...
